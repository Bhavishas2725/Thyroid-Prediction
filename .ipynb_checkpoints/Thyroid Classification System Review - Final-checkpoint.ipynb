# %% [markdown]
# #Thyroid Classification System

# %% [markdown]
# ##Importing Necessary Libraries

# %%
# !pip install pycaret

# %%
# !pip install joblib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pycaret.classification import *
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
#from sklearn.externals import joblib
import joblib
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Reading the Dataset

# %%
#df=pd.read_csv('Thyroid_Dataset.csv')
df=pd.read_csv('/content/drive/MyDrive/ProjectDatasets/Thyroid/Thyroid_Dataset.csv')

# %% [markdown]
# ##Displaying the Data

# %%
df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred'],
#       dtype='object')

# %% [markdown]
# ##Data Size

# %%
df.shape
# Out:
# (383, 17)

# %% [markdown]
# ##Checking Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %% [markdown]
# ##Checking for Duplicate values

# %%
print(df.duplicated().sum())
# Out:
# 19

# %%
df=df.drop_duplicates()

# %% [markdown]
# ##Checking for Null Values

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %% [markdown]
# ##Checking unique values in each column

# %%
df.nunique()
# Out:
# Age                     65
# Gender                   2
# Smoking                  2
# Hx Smoking               2
# Hx Radiothreapy          2
# Thyroid Function         5
# Physical Examination     5
# Adenopathy               6
# Pathology                4
# Focality                 2
# Risk                     3
# T                        7
# N                        3
# M                        2
# Stage                    5
# Response                 4
# Recurred                 2
# dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
    print('--------')
# Out:
# Age
# 31    21
# 27    13
# 30    12
# 33    12
# 28    11
#       ..
# 15     1
# 82     1
# 76     1
# 64     1
# 78     1
# Name: count, Length: 65, dtype: int64
# --------
# Gender
# F    293
# M     71
# Name: count, dtype: int64
# --------
# Smoking
# No     315
# Yes     49
# Name: count, dtype: int64
# --------
# Hx Smoking
# No     336
# Yes     28
# Name: count, dtype: int64
# --------
# Hx Radiothreapy
# No     357
# Yes      7
# Name: count, dtype: int64
# --------
# Thyroid Function
# Euthyroid                      313
# Clinical Hyperthyroidism        20
# Subclinical Hypothyroidism      14
# Clinical Hypothyroidism         12
# Subclinical Hyperthyroidism      5
# Name: count, dtype: int64
# --------
# Physical Examination
# Multinodular goiter            135
# Single nodular goiter-right    127
# Single nodular goiter-left      88
# Normal                           7
# Diffuse goiter                   7
# Name: count, dtype: int64
# --------
# Adenopathy
# ...

# %%
df.describe()
# Out:
#              Age
# count  364.00000
# mean    41.25000
# std     15.31436
# min     15.00000
# 25%     30.00000
# 50%     38.00000
# 75%     52.00000
# max     82.00000

# %%
cat_cols=['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
       'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
       'Focality', 'Stage']
num_cols=['Age']

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Age'])
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
import math
n = len(cat_cols)
cols = 3
rows = math.ceil(n / cols)

plt.figure(figsize=(15, rows * 4))

for i, col in enumerate(cat_cols, 1):
    plt.subplot(rows, cols, i)
    sns.countplot(data=df, x=col, hue='Recurred', palette='Set2')
    plt.title(f'{col} by Recurred')
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
le=LabelEncoder()
scaler=StandardScaler()

# %%
fin_df=df.copy().drop(columns=['T','N','M'],axis=1)

# %%
fin_df['Risk'] = fin_df['Risk'].replace({
    'Intermediate': 'High'
})

# %%
fin_df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#   Stage       Response Recurred
# 0     I  Indeterminate       No
# 1     I      Excellent       No
# ...

# %% [markdown]
# #Thyroid Risk Prediction

# %%
risk_pred_train=fin_df.drop(columns=['Recurred','Response'],axis=1)

# %%
risk_pred_train.columns
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'Stage'],
#       dtype='object')

# %%
risk_pred_train['Risk'].value_counts()
# Out:
# Risk
# Low     230
# High    134
# Name: count, dtype: int64

# %%
# risk_pred_train['Age_bin'] = pd.cut(
#     risk_pred_train['Age'],
#     bins=[0, 30, 45, 60, 120],
#     labels=[0, 1, 2, 3]
# )

# # Drop original Age
# risk_pred_train = risk_pred_train.drop(columns=['Age'])

# %% [markdown]
# ##Checking the best base model using Pycaret

# %%
clf = setup(
    data=risk_pred_train,
    target='Risk',
    session_id=42,
    normalize=False,
#     handle_unknown_categorical=True,
    fix_imbalance=True,
    fold=5
)
# Out:
# <style type="text/css">
# #T_db0ea_row10_col1, #T_db0ea_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_db0ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db0ea_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_db0ea_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db0ea_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_db0ea_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_db0ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db0ea_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_db0ea_row1_col1" class="data row1 col1" >Risk</td>
#     </tr>
#     <tr>
# ...

# %%
best_models = compare_models(sort='Accuracy')
# Out:
# <style type="text/css">
# #T_65f62 th {
#   text-align: left;
# }
# ...

# %%
risk_pred_train['Risk'] = risk_pred_train['Risk'].map({'Low': 0, 'High': 1})

# %%
risk_pred_train['Risk'] .value_counts()
# Out:
# Risk
# 0    230
# 1    134
# Name: count, dtype: int64

# %% [markdown]
# ##Encoding

# %%
label_encoders_risk = {}

for col in cat_cols:
    le = LabelEncoder()
    risk_pred_train[col] = le.fit_transform(risk_pred_train[col])
    label_encoders_risk[col] = le

# %%
risk_pred_train['Age'] = scaler.fit_transform(risk_pred_train[['Age']])

# %%
X = risk_pred_train.drop('Risk',axis=1)
y = risk_pred_train['Risk']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
cat_cols=['Gender',
 'Smoking',
 'Hx Smoking',
 'Hx Radiothreapy',
 'Thyroid Function',
 'Physical Examination',
 'Adenopathy',
 'Pathology',
 'Focality',
 'Stage']

# %% [markdown]
# ##Building the best model based on Pycaret results with hyperparameter tuning on Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(
    penalty='l2',
    C=1.0,
    solver='liblinear',
    class_weight='balanced',
    max_iter=1000,
    random_state=42
)

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=1000, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = log_reg.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.821917808219178

# %%
joblib.dump(label_encoders_risk, 'label_encoders_risk.pkl')
# Out:
# ['label_encoders_risk.pkl']

# %%
joblib.dump(X_train.columns.tolist(), 'feature_order_risk.pkl')
# Out:
# ['feature_order_risk.pkl']

# %%
joblib.dump(log_reg, 'logistic_risk_model.pkl')
# Out:
# ['logistic_risk_model.pkl']

# %%
joblib.dump(scaler, 'age_scaler_risk.pkl')
# Out:
# ['age_scaler_risk.pkl']

# %% [markdown]
# ##Model Predictions

# %%
label_encoders = joblib.load('label_encoders_risk.pkl')
feature_order = joblib.load('feature_order_risk.pkl')
model = joblib.load('logistic_risk_model.pkl')
scaler = joblib.load('age_scaler_risk.pkl')

# %%
#NO
custom_input = {
    'Age': 27,
    'Gender': 'F',
    'Smoking': 'No',
    'Hx Smoking': 'No',
    'Hx Radiothreapy': 'No',
    'Thyroid Function': 'Euthyroid',
    'Physical Examination': 'Single nodular goiter-left',
    'Adenopathy': 'No',
    'Pathology': 'Micropapillary',
    'Focality': 'Uni-Focal',
#     'Risk': 'Low',
    'Stage': 'I',
}

custom_df = pd.DataFrame([custom_input])

# %%
df = pd.DataFrame([custom_input])

for col, le in label_encoders.items():
    df[col] = le.transform(df[col])

df['Age'] = scaler.transform(df[['Age']])

df = df[feature_order]

pred = model.predict(df)[0]

result = 'High' if pred == 1 else 'Low'

print("Predicted Risk:", result)
# Out:
# Predicted Risk: Low

# %% [markdown]
# #Thyroid Recurrence Prediction

# %% [markdown]
# ##Checking the best base model using Pycaret

# %%
clf = setup(
    data=fin_df,
    target='Recurred',
    session_id=42,
    normalize=False,
#     handle_unknown_categorical=True,
    fix_imbalance=True,
    fold=5
)
# Out:
# <style type="text/css">
# #T_b4e15_row10_col1, #T_b4e15_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b4e15" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4e15_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b4e15_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4e15_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b4e15_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_b4e15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4e15_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b4e15_row1_col1" class="data row1 col1" >Recurred</td>
#     </tr>
#     <tr>
# ...

# %%
best_models = compare_models(sort='Accuracy')
# Out:
# <style type="text/css">
# #T_d63cd th {
#   text-align: left;
# }
# ...

# %%
recur_pred_train=fin_df.copy()

# %%
recur_pred_train['Recurred'] = recur_pred_train['Recurred'].map({'No': 0, 'Yes': 1})

# %%
cat_cols=['Gender',
 'Smoking',
 'Hx Smoking',
 'Hx Radiothreapy',
 'Thyroid Function',
 'Physical Examination',
 'Adenopathy',
 'Pathology',
 'Focality',
 'Stage','Risk','Response']

# %% [markdown]
# ##Encoding

# %%
label_encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    recur_pred_train[col] = le.fit_transform(recur_pred_train[col])
    label_encoders[col] = le

# %%
X = recur_pred_train.drop('Recurred',axis=1)
y = recur_pred_train['Recurred']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
import joblib
joblib.dump(label_encoders, 'label_encoders_recur.pkl')
# Out:
# ['label_encoders_recur.pkl']

# %%
joblib.dump(X_train.columns.tolist(), 'feature_order_recur.pkl')
# Out:
# ['feature_order_recur.pkl']

# %%
y.value_counts()
# Out:
# Recurred
# 0    256
# 1    108
# Name: count, dtype: int64

# %%
neg, pos = y_train.value_counts()
scale_pos_weight = neg / pos
scale_pos_weight
# Out:
# 2.383720930232558

# %% [markdown]
# ##Building the best model based on Pycaret results with hyperparameter tuning on XGBoost

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.03,
    max_depth=4,
    min_child_weight=1,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    reg_alpha=0.5,
    reg_lambda=1,
    scale_pos_weight=scale_pos_weight,
    objective='binary:logistic',
    eval_metric='logloss',
    random_state=42
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=0.1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, objective='binary:logistic', ...)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_pred = xgb_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9315068493150684
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95        51
#            1       0.84      0.95      0.89        22
#
#     accuracy                           0.93        73
#    macro avg       0.91      0.94      0.92        73
# weighted avg       0.94      0.93      0.93        73

# %%
joblib.dump(xgb_model, 'thyroid_xgb_recur.pkl')
# Out:
# ['thyroid_xgb_recur.pkl']

# %% [markdown]
# ##Model Prediction

# %%
#NO
custom_input = {
    'Age': 27,
    'Gender': 'F',
    'Smoking': 'No',
    'Hx Smoking': 'No',
    'Hx Radiothreapy': 'No',
    'Thyroid Function': 'Euthyroid',
    'Physical Examination': 'Single nodular goiter-left',
    'Adenopathy': 'No',
    'Pathology': 'Micropapillary',
    'Focality': 'Uni-Focal',
    'Risk': 'Low',
    'Stage': 'I',
    'Response':'Indeterminate'
}
#YES
custom_input = {
    'Age': 26,
    'Gender': 'F',
    'Smoking': 'No',
    'Hx Smoking': 'No',
    'Hx Radiothreapy': 'No',
    'Thyroid Function': 'Euthyroid',
    'Physical Examination': 'Normal',
    'Adenopathy': 'Extensive',
    'Pathology': 'Papillary',
    'Focality': 'Uni-Focal',
    'Risk': 'Intermediate',
    'Stage': 'I',
    'Response': 'Structural'
}
custom_df = pd.DataFrame([custom_input])

# %%
def encode_custom_input(df, label_encoders):
    df_encoded = df.copy()

    for col, le in label_encoders.items():
        if col in df_encoded.columns:
            df_encoded[col] = df_encoded[col].apply(
                lambda x: le.transform([x])[0] if x in le.classes_ else -1
            )
    return df_encoded

custom_df_encoded = encode_custom_input(custom_df, label_encoders)

# %%
prediction = xgb_model.predict(custom_df_encoded)

print("Prediction:", "Yes" if prediction[0] == 1 else "No")
# Out:
# Prediction: Yes

# %%
import joblib

# Save your trained model
joblib.dump(model, "thyroid_model.pkl")

# Save your scaler (if you used StandardScaler)
joblib.dump(scaler, "scaler.pkl")

print("Saved!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import joblib
#       3 # Save your trained model
# ----> 4 joblib.dump(model, "thyroid_model.pkl")
#       6 # Save your scaler (if you used StandardScaler)
#       7 joblib.dump(scaler, "scaler.pkl")
#
# NameError: name 'model' is not defined
